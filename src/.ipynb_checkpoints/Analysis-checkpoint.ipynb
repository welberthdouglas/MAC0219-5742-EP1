# %% [markdown]
# # Imports

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

plt.style.use(['science','no-latex'])

# %% [markdown]
# # Loading Results
# TODO
#
# - impacto de IO e MALLOC:
#     - graficos tempo X tamanho da entrada X com e sem io para os 4 casos (com barras de erros). Existe diferença consistente entre as diferentes regiões?
#     - graficos de barra com tempo de IO (diferenca entre com e sem) em porcentagem do total. responder se é consistentee
#
# - diferenças nas tres versões (avaliar com 4 threads):
#     - grafico tempo X tamanho da entrada X seq_omp_pth para os 4 casos
#     - grafico de barras - redução percentual do tempo de computação para cada programa para cada tamanho de entrada
#
# - diferenças das regiões (avaliar com 4 threads):
#     - grafico tempo X tamanho da entrada X região para os 3 tipos de código
#     - imagem das quatro regiões e explicar como isso afeta o tempo de execução
#
# - diferenças de threads:
#     - grafico tempo X n_threads X seq_omp_pth -> fazer para tres tamanhos de entrada padrao - 2^0, 2^3,2^5
#     - explicar comportamento dado n processadores

# %%
res = pd.read_csv("experiments.csv")

# %%
f = res.query("VERSION == 'mandelbrot_seq' and REGION == 'elephant'")

# %%
fig,ax = plt.subplots(figsize=(15,10));
ax.plot(f.query("IO_MALLOC_FLAG == 1").SIZE,f.query("IO_MALLOC_FLAG == 1").AVG_TOTAL_TIME, label="Com IO e malloc"); #,'k--',dashes=[10,8]
ax.plot(f.query("IO_MALLOC_FLAG == 0").SIZE,f.query("IO_MALLOC_FLAG == 0").AVG_TOTAL_TIME, label="Sem IO e malloc");
ax.set_title("Efeito do Overhead de IO e Alocação de Memória",fontsize=18, pad = 15);
ax.set_xlabel('Tamanho da Imagem [pixeis]', fontsize=15, labelpad = 15);
ax.set_ylabel('Tempo [s]', fontsize=15, rotation = 0, labelpad = 40);
ax.tick_params(axis='both', which='major', labelsize=15, pad=15);
ax.legend(loc='lower right',fontsize=15);
ax.set_xlim([0,8200]);

# %%
f
# Out:
#             VERSION    REGION  IO_MALLOC_FLAG  SIZE  THREAD_NUM  \
# 2    mandelbrot_seq  elephant               0    16           1
# 6    mandelbrot_seq  elephant               0    32           1
# 10   mandelbrot_seq  elephant               0    64           1
# 14   mandelbrot_seq  elephant               0   128           1
# 18   mandelbrot_seq  elephant               0   256           1
# 22   mandelbrot_seq  elephant               0   512           1
# 26   mandelbrot_seq  elephant               0  1024           1
# 30   mandelbrot_seq  elephant               0  2048           1
# 34   mandelbrot_seq  elephant               0  4096           1
# 38   mandelbrot_seq  elephant               0  8192           1
# 522  mandelbrot_seq  elephant               1    16           1
# 526  mandelbrot_seq  elephant               1    32           1
# 530  mandelbrot_seq  elephant               1    64           1
# 534  mandelbrot_seq  elephant               1   128           1
# 538  mandelbrot_seq  elephant               1   256           1
# 542  mandelbrot_seq  elephant               1   512           1
# 546  mandelbrot_seq  elephant               1  1024           1
# 550  mandelbrot_seq  elephant               1  2048           1
# 554  mandelbrot_seq  elephant               1  4096           1
# 558  mandelbrot_seq  elephant               1  8192           1
#
#      AVG_TOTAL_TIME  STD_TOTAL_TIME   %STD
# 2          0.001201        0.000110  9.15%
# 6          0.001980        0.000121  6.12%
# 10         0.005387        0.000137  2.55%
# 14         0.017511        0.000506  2.89%
# 18         0.058590        0.000486  0.83%
# 22         0.226490        0.002310  1.02%
# 26         0.907450        0.006240  0.69%
# 30         3.567400        0.013400  0.38%
# 34        14.158800        0.029900  0.21%
# 38        57.086000        0.261000  0.46%
# 522        0.001408        0.000134  9.51%
# 526        0.002489        0.000079  3.20%
# 530        0.006410        0.000131  2.05%
# 534        0.018578        0.000436  2.35%
# 538        0.063023        0.000924  1.47%
# 542        0.242220        0.002030  0.84%
# 546        0.960300        0.007770  0.81%
# 550        3.824900        0.020600  0.54%
# 554       15.086600        0.028600  0.19%
# 558       62.448000        0.777000  1.24%

# %%
f
# Out:
#             VERSION REGION  IO_MALLOC_FLAG  SIZE  THREAD_NUM  AVG_TOTAL_TIME  \
# 0    mandelbrot_seq   full               0    16           1        0.000733
# 4    mandelbrot_seq   full               0    32           1        0.000870
# 8    mandelbrot_seq   full               0    64           1        0.001346
# 12   mandelbrot_seq   full               0   128           1        0.003455
# 16   mandelbrot_seq   full               0   256           1        0.009920
# 20   mandelbrot_seq   full               0   512           1        0.034459
# 24   mandelbrot_seq   full               0  1024           1        0.130660
# 28   mandelbrot_seq   full               0  2048           1        0.512520
# 32   mandelbrot_seq   full               0  4096           1        2.029260
# 36   mandelbrot_seq   full               0  8192           1        8.162500
# 520  mandelbrot_seq   full               1    16           1        0.001118
# 524  mandelbrot_seq   full               1    32           1        0.001440
# 528  mandelbrot_seq   full               1    64           1        0.002265
# 532  mandelbrot_seq   full               1   128           1        0.005260
# 536  mandelbrot_seq   full               1   256           1        0.014991
# 540  mandelbrot_seq   full               1   512           1        0.052180
# 544  mandelbrot_seq   full               1  1024           1        0.197160
# 548  mandelbrot_seq   full               1  2048           1        0.764290
# 552  mandelbrot_seq   full               1  4096           1        3.078900
# 556  mandelbrot_seq   full               1  8192           1       12.106400
#
#      STD_TOTAL_TIME   %STD
# 0          0.000051  6.92%
# 4          0.000032  3.67%
# 8          0.000055  4.05%
# 12         0.000112  3.24%
# 16         0.000238  2.40%
# 20         0.000807  2.34%
# 24         0.000820  0.63%
# 28         0.002760  0.54%
# 32         0.002840  0.14%
# 36         0.095700  1.17%
# 520        0.000090  8.08%
# 524        0.000106  7.39%
# 528        0.000117  5.16%
# 532        0.000275  5.23%
# 536        0.000356  2.38%
# 540        0.001120  2.15%
# 544        0.002320  1.18%
# 548        0.006790  0.89%
# 552        0.065100  2.11%
# 556        0.047700  0.39%

# %%
res
# Out:
#             VERSION    REGION  IO_MALLOC_FLAG  SIZE  THREAD_NUM  \
# 0    mandelbrot_seq      full               0    16           1
# 1    mandelbrot_seq  seahorse               0    16           1
# 2    mandelbrot_seq  elephant               0    16           1
# 3    mandelbrot_seq    spiral               0    16           1
# 4    mandelbrot_seq      full               0    32           1
# ..              ...       ...             ...   ...         ...
# 555  mandelbrot_seq    spiral               1  4096           1
# 556  mandelbrot_seq      full               1  8192           1
# 557  mandelbrot_seq  seahorse               1  8192           1
# 558  mandelbrot_seq  elephant               1  8192           1
# 559  mandelbrot_seq    spiral               1  8192           1
#
#      AVG_TOTAL_TIME  STD_TOTAL_TIME   %STD
# 0          0.000733        0.000051  6.92%
# 1          0.000961        0.000058  5.99%
# 2          0.001201        0.000110  9.15%
# 3          0.001057        0.000083  7.86%
# 4          0.000870        0.000032  3.67%
# ..              ...             ...    ...
# 555       18.255000        0.176000  0.96%
# 556       12.106400        0.047700  0.39%
# 557       64.631000        0.545000  0.84%
# 558       62.448000        0.777000  1.24%
# 559       72.497000        0.646000  0.89%
#
# [560 rows x 8 columns]
